# %% [markdown]
# ### Neural Networks and Deep Learning Project
# # Singing-Voice Separation Using RNN
# #### Author: Xing Yuan, Yizhou Wang, Wanjia Zhang

# %%
env THEANO_FLAGS=floatX=float64
# Out:
# env: THEANO_FLAGS=floatX=float64

# %% [markdown]
# ### Experiment 1:
#
#     Model: RNN + Original Mask
#     Parameters: n_epoch=30,
#                 lr=0.05,
#                 n_hidden1=1000,
#                 n_hidden2=1026 (2*513),
#                 batch_size=100,
#                 rou=0.8

# %%
from rnn_nw2 import *
rnn_test (n_epoch=30, lr=0.05, n_hidden1=1000, n_hidden2=2, batch_size=100, rou=0.8, verbose=True, decay=True)
# Out:
# ... loading data
#     ... dim of train_x is (171, 100, 513)
#     ... dim of valid_x is (4, 100, 513)
#     ... dim of test_x is (825, 100, 513)
# ... building the model
# ... training
#     ... training iteration 0
#     ... training iteration 50
#     ... training iteration 100
#     ... training iteration 150
# ... testing
#     ... test on training set
#     ... test on validation set
#     ... test on test set
# epoch 0, valid SDR 3.237722
# NEW BEST: epoch 0, training SDR 5.216485 , valid SDR 3.237722 , best test SDR 3.229896
# ... training
#     ... training iteration 0
#     ... training iteration 50
#     ... training iteration 100
#     ... training iteration 150
# ... testing
#     ... test on training set
#     ... test on validation set
#     ... test on test set
# epoch 1, valid SDR 3.693586
# NEW BEST: epoch 1, training SDR 5.811807 , valid SDR 3.693586 , best test SDR 3.398469
# ... training
#     ... training iteration 0
#     ... training iteration 50
# ...

# %% [markdown]
# **Results for experiment 1:**
#
#     BEST RESULT: epoch 10, valid SDR 4.002834 , best test SDR 3.573102

# %% [markdown]
# ### Experiment 2:
#
#     Model: RNN + Original Mask + Data Augmentation (10 times)
#     Parameters: n_epoch=30,
#                 lr=0.05,
#                 n_hidden1=1000,
#                 n_hidden2=1026 (2*513),
#                 batch_size=100,
#                 rou=0.8

# %%
from rnn_nw2 import *
rnn_test (n_epoch=30, lr=0.05, n_hidden1=1000, n_hidden2=2, batch_size=100, rou=0.8, verbose=True, decay=True)
# Out:
# ... loading data
#     ... dim of train_x is (1710, 100, 513)
#     ... dim of valid_x is (4, 100, 513)
#     ... dim of test_x is (825, 100, 513)
# ... building the model
# ... training
#     ... training iteration 0
#     ... training iteration 100
#     ... training iteration 200
#     ... training iteration 300
#     ... training iteration 400
#     ... training iteration 500
#     ... training iteration 600
#     ... training iteration 700
#     ... training iteration 800
#     ... training iteration 900
#     ... training iteration 1000
#     ... training iteration 1100
#     ... training iteration 1200
#     ... training iteration 1300
#     ... training iteration 1400
#     ... training iteration 1500
#     ... training iteration 1600
#     ... training iteration 1700
# ... testing
#     ... test on training set
#     ... test on validation set
#     ... test on test set
# epoch 0, valid SDR 4.375742
# ...

# %% [markdown]
# **Results for experiment 2:**
#
#     BEST RESULT: epoch 9, valid SDR 4.934914 , best test SDR 4.742873

# %% [markdown]
# ### Experiment 3:
#
#     Model: RNN + softmax Mask + Data Augmentation (10 times)
#     Parameters: n_epoch=30,
#                 lr=0.05,
#                 n_hidden1=1000,
#                 n_hidden2=1026 (2*513),
#                 batch_size=100,
#                 rou=0.8

# %%
from rnn_nw2 import *
rnn_test (n_epoch=30, lr=0.05, n_hidden1=1000, n_hidden2=2, batch_size=100, rou=0.8, verbose=True, decay=True)
# Out:
# ... loading data
#     ... dim of train_x is (1710, 100, 513)
#     ... dim of valid_x is (4, 100, 513)
#     ... dim of test_x is (825, 100, 513)
# ... building the model
# ... training
#     ... training iteration 0
#     ... training iteration 100
#     ... training iteration 200
#     ... training iteration 300
#     ... training iteration 400
#     ... training iteration 500
#     ... training iteration 600
#     ... training iteration 700
#     ... training iteration 800
#     ... training iteration 900
#     ... training iteration 1000
#     ... training iteration 1100
#     ... training iteration 1200
#     ... training iteration 1300
#     ... training iteration 1400
#     ... training iteration 1500
#     ... training iteration 1600
#     ... training iteration 1700
# ... testing
#     ... test on training set
#     ... test on validation set
#     ... test on test set
# epoch 0, valid SDR 4.789422
# ...

# %% [markdown]
# **Results for experiment 3:**
#
#     BEST RESULT: epoch 17, valid SDR 6.198712 , best test SDR 6.110253
