# %% [markdown]
# # ECBM E6040 Homework 2 - Programming Problem

# %% [markdown]
# **Yizhou Wang   UNI: yw2875**

# %%
from hw2b import load_data, LogisticRegression, HiddenLayer, MLP, myMLP, test_mlp
# Out:
# Using gpu device 0: GRID K520

# %% [markdown]
# ### Problem b: Bullet 2: Comparison between _tanh_ and _softmax_

# %% [markdown]
# Use activation function **```tanh()```**.

# %%
test_mlp( n_hl=2, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ...

# %% [markdown]
# Use activation function **```softmax()```**.

# %%
test_mlp( n_hl=2, act_fun='softmax' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# Optimization complete. Best validation score of 81.161202 % obtained at iteration 3296, with test performance 80.415065 %
# The code for file hw2b.py ran for 0.97m

# %% [markdown]
# The results above show that for **```tanh()```**, the best validation score of 16.530055% obtained at iteration 276864, with test performance 18.481937%. While for **```softmax()```**, the best validation score of 81.161202% obtained at iteration 3296, with test performance 80.415065%.

# %% [markdown]
# The result of test performance using **```tanh()```** is much smaller than using **```softmax()```**, but using **```tanh()```** is also much slower than using **```softmax()```**.

# %% [markdown]
# ### Problem b: Bullet 3: Experiment with the number of hidden layers

# %% [markdown]
# Using the default parameters with the number of hidden layers $n_{hl} = \{1,3,5,7\} $. The default parameters are ```"learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000, batch_size=20, n_hidden=500, verbose=False, act_fun='tanh'"```.

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=500, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=500, verbose=False, n_hl=3, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... building 3 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=500, verbose=False, n_hl=5, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... building 3 hidden layer
# ... building 4 hidden layer
# ... building 5 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=500, verbose=False, n_hl=7, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... building 3 hidden layer
# ... building 4 hidden layer
# ... building 5 hidden layer
# ... building 6 hidden layer
# ... building 7 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# Optimization complete. Best validation score of 21.448087 % obtained at iteration 46144, with test performance 22.897771 %
# The code for file hw2b.py ran for 13.87m

# %% [markdown]
# When $n_{hl} = 1$, the result of optimization is: Best validation score of $19.904372\%$ obtained at iteration 355968, with test performance $21.764028\%$.
#
# When $n_{hl} = 3$, the result of optimization is: Best validation score of $16.516393\%$ obtained at iteration 240608, with test performance $19.581091\%$.
#
# When $n_{hl} = 5$, the result of optimization is: Best validation score of $15.163934\%$ obtained at iteration 721824, with test performance $18.155265\%$.
#
# When $n_{hl} = 7$, the result of optimization is: Best validation score of $21.448087\%$ obtained at iteration 46144, with test performance $22.897771\%$.

# %% [markdown]
# In the last test, however, the performance is really bad even it has 7 hidden layers. From the theory as well as codes, we can infer that this mainly because the parameter of ```"patience"```. Hence, set ```"patience = 20000"``` and also set ```"batch_size = 30"```. The result is shown below.

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=30, n_hidden=500, verbose=False, n_hl=7, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... building 3 hidden layer
# ... building 4 hidden layer
# ... building 5 hidden layer
# ... building 6 hidden layer
# ... building 7 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ...

# %% [markdown]
# It turns out that the best validation score of $14.494536\%$ obtained at iteration 841451, with test performance $17.747020\%$. This is better than the result of networks with 5 hidden layers.

# %% [markdown]
# **Plot the result** (reproducing Figure 1)

# %%
% matplotlib inline
import numpy as np
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
x = [1,3,5,7]
y = list(100 - np.array([21.764028,19.581091,18.155265,17.747020]))
plt.plot(x, y, '-o')
plt.axis([0, 8, 77, 83])
plt.xlabel('Number of Layers')
plt.ylabel('Test Accuracy [%]')

# %% [markdown]
# **Document the choice of parameters, and discuss what you discover.**

# %% [markdown]
# Then, to determine the role of each parameters, some tests are following with respect to networks with 1 hidden layer.

# %%
test_mlp(learning_rate=0.1, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=40, n_hidden=500, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# Optimization complete. Best validation score of 52.568306 % obtained at iteration 6592, with test performance 54.188462 %
# The code for file hw2b.py ran for 0.91m

# %%
test_mlp(learning_rate=0.01, L1_reg=0.001, L2_reg=0.0001, n_epochs=1000,
             batch_size=40, n_hidden=500, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# Optimization complete. Best validation score of 81.161202 % obtained at iteration 1648, with test performance 80.415385 %
# The code for file hw2b.py ran for 1.28m

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.001, n_epochs=1000,
             batch_size=40, n_hidden=500, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=40, n_hidden=500, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ...

# %% [markdown]
# From the above results, we can conclude that
# 1. ```learning rate```: Performance drop when learning rate grows.
# 2. ```L1_reg``` & ```L2_reg```: Performance drop when these parameters grows.
# 3. ```batch_size```: Performance drop a little when batch_size grows, while running time decreases.

# %% [markdown]
# ### Problem b: Bullet 4: Experiment with the number of hidden layers, but fix the total number of neurons

# %%
from math import floor

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=floor(840/1), verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=floor(840/2), verbose=False, n_hl=2, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=floor(840/3), verbose=False, n_hl=3, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... building 3 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=floor(840/4), verbose=False, n_hl=4, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... building 3 hidden layer
# ... building 4 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=floor(840/5), verbose=False, n_hl=5, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... building 3 hidden layer
# ... building 4 hidden layer
# ... building 5 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=floor(840/6), verbose=False, n_hl=6, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... building 3 hidden layer
# ... building 4 hidden layer
# ... building 5 hidden layer
# ... building 6 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ...

# %% [markdown]
# Plot the result (reproducing Figure 2)

# %%
% matplotlib inline
import numpy as np
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6]
y = list(100 - np.array([24.811683,18.966180,18.247502,18.811538,20.830769,22.003846]))
plt.plot(x, y, '-o')
plt.axis([0, 8, 74, 83])
plt.xlabel('Number of Hidden Layers')
plt.ylabel('Test Accuracy [%]')

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.

# %% [markdown]
# The test accuracy peak at almost $82\%$ when the number of hidden layers is 3. Then it drops not only when the number of hidden layers decreases, but also when it grows.

# %% [markdown]
# ### Problem b: Bullet 5: Experiment with the number of neurons in hidden layers, but fix the number of hidden layers

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=50, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=100, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=250, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=500, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=750, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=1000, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ...

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
             batch_size=20, n_hidden=1500, verbose=False, n_hl=1, act_fun='tanh' )
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ...

# %% [markdown]
# Plot the result (reproducing Figure 3)

# %%
% matplotlib inline
import numpy as np
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
x = [50,100,250,500,750,1000,1500]
y = list(100 - np.array([24.477325,24.208301,21.641045,21.764028,20.499616,24.419677,20.969231]))
plt.plot(x, y, '-o')
plt.axis([0, 1600, 70, 83])
plt.xlabel('Number of Neurons in Hidden Layers')
plt.ylabel('Test Accuracy [%]')

# %% [markdown]
# Document the choice of parameters, and discuss what you discover.

# %% [markdown]
# The test accuracy fluctuates while the number of neurons in hidden layers. The highest test accuracy reached about $80\%$ when the number of neurons in hiddenlayers is 750.

# %% [markdown]
# ### Problem c: Bullet 1: Implement MLP(with dropout) with the parameters specified

# %%
from hw2c import load_data, LogisticRegression, DropoutHiddenLayer, test_mlp_dropout
# Out:
# Using gpu device 0: GRID K520

# %%
test_mlp_dropout(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=500,
             batch_size=20, n_hidden=500, verbose=False, hidlayers=2)
# Out:
# ... loading data
# ... building the model
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ... epoch 60
# ... epoch 61
# ... epoch 62
# ... epoch 63
# ...

# %% [markdown]
# ### Problem c: Bullet 2: Implement MLP(without dropout) with the parameters specified

# %%
test_mlp(learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=500,
             batch_size=20, n_hidden=500, verbose=False, n_hl=2)
# Out:
# ... loading data
# ... building the model
# ... building 1 hidden layer
# ... building 2 hidden layer
# ... training
# ... epoch 1
# ... epoch 2
# ... epoch 3
# ... epoch 4
# ... epoch 5
# ... epoch 6
# ... epoch 7
# ... epoch 8
# ... epoch 9
# ... epoch 10
# ... epoch 11
# ... epoch 12
# ... epoch 13
# ... epoch 14
# ... epoch 15
# ... epoch 16
# ... epoch 17
# ... epoch 18
# ... epoch 19
# ... epoch 20
# ... epoch 21
# ... epoch 22
# ... epoch 23
# ... epoch 24
# ... epoch 25
# ... epoch 26
# ... epoch 27
# ... epoch 28
# ... epoch 29
# ... epoch 30
# ... epoch 31
# ... epoch 32
# ... epoch 33
# ... epoch 34
# ... epoch 35
# ... epoch 36
# ... epoch 37
# ... epoch 38
# ... epoch 39
# ... epoch 40
# ... epoch 41
# ... epoch 42
# ... epoch 43
# ... epoch 44
# ... epoch 45
# ... epoch 46
# ... epoch 47
# ... epoch 48
# ... epoch 49
# ... epoch 50
# ... epoch 51
# ... epoch 52
# ... epoch 53
# ... epoch 54
# ... epoch 55
# ... epoch 56
# ... epoch 57
# ... epoch 58
# ... epoch 59
# ...

# %% [markdown]
# ### Problem c: Bullet 2: Compare the two cases

# %% [markdown]
# From the solutions above, we can see that MLP with dropout performs better than MLP without dropout. But the running time would be longer.
